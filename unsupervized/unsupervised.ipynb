# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import decomposition
from sklearn import datasets
import seaborn as sns

# %% [markdown]
# # DECOMPOSITION

# %% [markdown]
# ##  IRIS

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
X.shape, y.shape
# Out:
# ((150, 4), (150,))

# %%
#визуализиурйте данные
##############################################
#              YOU CODE HERE                 #
##############################################

##############################################
#              YOU CODE HERE                 #
##############################################

# %% [markdown]
# ### PCA

# %%
#Примеените PCA из модуля decomposition с параметром n_components=2
##############################################
#              YOU CODE HERE                 #
##############################################

##############################################
#              YOU CODE HERE                 #
##############################################

# %%
#визуализируйте данные после  PCA
##############################################
#              YOU CODE HERE                 #
##############################################

##############################################
#              YOU CODE HERE                 #
##############################################

# %%
#Что поменяется, если отцентровать данные?
##############################################
#              YOU CODE HERE                 #
##############################################

##############################################
#              YOU CODE HERE                 #
##############################################

# %% [markdown]
# ### NMF

# %%
#Примеените NMF из модуля decomposition.nmf с параметром n_components=2
#Визуализируйтее данные
##############################################
#              YOU CODE HERE                 #
##############################################

##############################################
#              YOU CODE HERE                 #
##############################################

# %% [markdown]
# ### Kernel PCA

# %%
#Примеените KernelPCA из модуля decomposition с параметром n_components=2
#Визуализируйтее данные
##############################################
#              YOU CODE HERE                 #
##############################################

##############################################
#              YOU CODE HERE                 #
##############################################

# %%
#Примеените KernelPCA из модуля decomposition с параметром n_components=2
#Визуализируйтее данные
##############################################
#              YOU CODE HERE                 #
##############################################

##############################################
#              YOU CODE HERE                 #
##############################################

# %% [markdown]
# ### T-SNE

# %%
from sklearn import manifold

# %%
#Примеените PCA из модуля decomposition с параметром n_components=2
#Визуализируйтее данные
##############################################
#              YOU CODE HERE                 #
##############################################

##############################################
#              YOU CODE HERE                 #
##############################################

# %% [markdown]
# ### SpectralEmbedding

# %%
#Визуализируйтее данные
##############################################
#              YOU CODE HERE                 #
##############################################

##############################################
#              YOU CODE HERE                 #
##############################################

# %% [markdown]
# ## DIGITS

# %%
digits = datasets.load_digits()
X = digits.data
y = digits.target
n_neighbors = 10

# %%
pca = decomposition.PCA(n_components=2)
pca.fit(X)
X_pca = pca.transform(X)

plt.figure(figsize=(12,10))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, 
            edgecolor='none', alpha=0.7, s=40, 
            cmap=plt.cm.get_cmap('nipy_spectral', 10))
plt.colorbar()
plt.show()

# %%
# Примените:
# - t-SNE
# - LLE (LocallyLinearEmbedding)
# - LTSA (LocallyLinearEmbedding(method='ltsa'))
# - Hessian LLE (LocallyLinearEmbedding(method='hessian', ))
# - Modified LLE (LocallyLinearEmbedding(method='modified'))
# - Isomap MDS
# - SpectralEmbedding
##############################################
#              YOU CODE HERE                 #
##############################################

##############################################
#              YOU CODE HERE                 #
##############################################

# %% [markdown]
# ## Scurve

# %%
n_points = 1000
X, y = datasets.samples_generator.make_s_curve(n_points, random_state=0)
n_neighbors = 10
n_components = 2

# %%
# Примените:
# - PCA
# - t-SNE
# - LLE (LocallyLinearEmbedding)
# - LTSA (LocallyLinearEmbedding(method='ltsa'))
# - Hessian LLE (LocallyLinearEmbedding(method='hessian', ))
# - Modified LLE (LocallyLinearEmbedding(method='modified'))
# - Isomap MDS
# - SpectralEmbedding
##############################################
#              YOU CODE HERE                 #
##############################################

##############################################
#              YOU CODE HERE                 #
##############################################

# %% [markdown]
# # CLUSTERING

# %%
X, y = datasets.make_circles(500, noise=0.05, factor=0.4)
X *= 10

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
from sklearn import cluster, metrics

# %%
# допишие функцию
def clustering_report(y_true, y_pred, X=None):
    ARI = # use metrics
    AMI = # use metrics
    Vms = # use metrics
    result = [ARI, AMI, Vms]
    cols = ['ARI', 'AMI', 'V-mesure']
              
    if X is not None:
        sil = # use metrics
        result.append(sil)
        cols.append('Silhouette')
    
    return pd.DataFrame([result],columns=cols)
# Out:
#   File "<ipython-input-25-270d1877dea9>", line 3
#     ARI = # use metrics
#                        ^
# SyntaxError: invalid syntax

# %%
#Check with ideal case
clustering_report(y, y, X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-fdf3751839bb> in <module>
#       1 #Check with ideal case
# ----> 2 clustering_report(y, y, X)
#
# NameError: name 'clustering_report' is not defined

# %%
#Используйте kMeans, визуализируйте результат и оцените качество
##############################################
#              YOU CODE HERE                 #
##############################################

##############################################
#              YOU CODE HERE                 #
##############################################

# %%
#Используйте AgglomerativeClustering, визуализируйте результат и оцените качество
##############################################
#              YOU CODE HERE                 #
##############################################

##############################################
#              YOU CODE HERE                 #
##############################################

# %%
#Используйте DBSCAN, визуализируйте результат и оцените качество
##############################################
#              YOU CODE HERE                 #
##############################################

##############################################
#              YOU CODE HERE                 #
##############################################
